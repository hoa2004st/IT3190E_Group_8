# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DeepLearning/Yolov5
# Out:
# /content/drive/MyDrive/DeepLearning/Yolov5

# %%
# !yolo task=detect mode=train epochs=100 batch=32 plots=True model="/content/drive/MyDrive/DeepLearning/Yolov5/yolov5nu.pt" data="/content/drive/MyDrive/DeepLearning/Dataset/mydataset.yaml"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# %cd /content/drive/MyDrive/DeepLearning/Yolov5
#wandb api: 5f7965c1911f9eb999fd18ec8b1f951a1c982db4
model_path = "/content/drive/MyDrive/DeepLearning/Yolov10/runs/detect/train/weights/best.pt"
best_model = YOLO(model_path)

result = best_model(source='/content/drive/MyDrive/DeepLearning/Dataset/train/images/airport_102_jpg.rf.0bc87c7c57f68d9a0acb281b532ce2f8.jpg', conf=0.25, save=True)
# Out:
# /content/drive/MyDrive/DeepLearning/Yolov5
#
# image 1/1 /content/drive/MyDrive/DeepLearning/Dataset/train/images/airport_102_jpg.rf.0bc87c7c57f68d9a0acb281b532ce2f8.jpg: 640x640 12 airplanes, 10.2ms
# Speed: 5.2ms preprocess, 10.2ms inference, 27.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
