# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 23.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DeepLearning/Yolov8l
# Out:
# /content/drive/MyDrive/DeepLearning/Yolov8l

# %%
# !yolo task=detect mode=train epochs=100 batch=32 plots=True model="/content/drive/MyDrive/DeepLearning/Yolov8l/yolov8l.pt" data="/content/drive/MyDrive/DeepLearning/Dataset/mydataset.yaml"
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# %cd /content/drive/MyDrive/DeepLearning/Yolov8l
#wandb api: 5f7965c1911f9eb999fd18ec8b1f951a1c982db4
model_path = "/content/drive/MyDrive/DeepLearning/Yolov8l/runs/detect/train4/weights/best.pt"
best_model = YOLO(model_path)

result = best_model(source='/content/drive/MyDrive/DeepLearning/Dataset/train/images/airport_102_jpg.rf.0bc87c7c57f68d9a0acb281b532ce2f8.jpg', conf=0.25, save=True)
# Out:
# /content/drive/MyDrive/DeepLearning/Yolov8l
#
# image 1/1 /content/drive/MyDrive/DeepLearning/Dataset/train/images/airport_102_jpg.rf.0bc87c7c57f68d9a0acb281b532ce2f8.jpg: 640x640 12 airplanes, 62.5ms
# Speed: 5.0ms preprocess, 62.5ms inference, 726.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
